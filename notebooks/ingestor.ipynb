# %% [markdown]
# ## Simple ETL ingestor pipeline to upload data to Zilliz cloud vector database

# %% [markdown]
# #### Step 1 : Text processing

# %%
import pandas as pd

# %%
# load data
file_name = "crops_state (1).csv"

metadata = {
    "source": "Department of Statistics Malaysia",
    "dataset_name": "Crop Area and Production by State",
    "source_url": "https://www.dosm.gov.my",
    "data_year": "2017-2022",
    "file_name" : f'{file_name}'
}

df = pd.read_csv(f'/home/digital_dungeon01/rag-chatbot-mvp/database/data-collection/{file_name}')
print(df.head())
# Out:
#       state        date   crop_type  planted_area  production
# 0  Malaysia  2017-01-01  cash_crops       20763.1    217847.5
# 1  Malaysia  2018-01-01  cash_crops       19028.2    215087.6
# 2  Malaysia  2019-01-01  cash_crops       17082.0    221310.2
# 3  Malaysia  2020-01-01  cash_crops       19090.9    223506.8
# 4  Malaysia  2021-01-01  cash_crops       20070.3    239011.9

# %%
def row_to_text(row):
    return (
        f"In {row['state']}, on {row['date']}, "
        f"the crop type is {row['crop_type']} with a planted area of "
        f"{row['planted_area']} hectares that produced {row['production']} tonnes."
    )

# %%
df["text"] = df.apply(row_to_text, axis=1) 
df_processed = df 
df_processed.head()
# Out:
#       state        date   crop_type  planted_area  production  \
# 0  Malaysia  2017-01-01  cash_crops       20763.1    217847.5
# 1  Malaysia  2018-01-01  cash_crops       19028.2    215087.6
# 2  Malaysia  2019-01-01  cash_crops       17082.0    221310.2
# 3  Malaysia  2020-01-01  cash_crops       19090.9    223506.8
# 4  Malaysia  2021-01-01  cash_crops       20070.3    239011.9
#
#                                                 text
# 0  In Malaysia, on 2017-01-01, the crop type is c...
# 1  In Malaysia, on 2018-01-01, the crop type is c...
# 2  In Malaysia, on 2019-01-01, the crop type is c...
# 3  In Malaysia, on 2020-01-01, the crop type is c...
# 4  In Malaysia, on 2021-01-01, the crop type is c...

# %% [markdown]
# #### Step 2 : Text Chunking

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from datetime import datetime

# %%
splitter = RecursiveCharacterTextSplitter (chunk_size=200, chunk_overlap=50)

chunks = []
chunk_counter = 0

# Loop each row
for _, row in df_processed.iterrows():
    split_texts = splitter.split_text(row["text"])
    chunk_counter += 1
    
    for chunk_text in split_texts:
        chunks.append({
            "text": chunk_text,
            
            # data fields
            "state": str(row["state"]),
            "date": str(row["date"]),
            "crop_type": str(row["crop_type"]),
            "planted_area": float(row["planted_area"]),
            "production": float(row["production"]),
            
            # metadata
            "source": metadata["source"],
            "dataset_name": metadata["dataset_name"],
            "source_url": metadata["source_url"],
            "data_year": metadata["data_year"],
            
            # tracking
            "file_name" : metadata["file_name"],
            "chunk_id": f"chunk_{chunk_counter:06d}",
            "created_at": datetime.now().isoformat()
            
        })

# %%
print(f"total : {len(chunks)}")
print(chunks[:2])
# Out:
# total : 864
# [{'text': 'In Malaysia, on 2017-01-01, the crop type is cash_crops with a planted area of 20763.1 hectares that produced 217847.5 tonnes.', 'state': 'Malaysia', 'date': '2017-01-01', 'crop_type': 'cash_crops', 'planted_area': 20763.1, 'production': 217847.5, 'source': 'Department of Statistics Malaysia', 'dataset_name': 'Crop Area and Production by State', 'source_url': 'https://www.dosm.gov.my', 'data_year': '2017-2022', 'file_name': 'crops_state (1).csv', 'chunk_id': 'chunk_000001', 'created_at': '2025-10-25T02:15:57.455629'}, {'text': 'In Malaysia, on 2018-01-01, the crop type is cash_crops with a planted area of 19028.2 hectares that produced 215087.6 tonnes.', 'state': 'Malaysia', 'date': '2018-01-01', 'crop_type': 'cash_crops', 'planted_area': 19028.2, 'production': 215087.6, 'source': 'Department of Statistics Malaysia', 'dataset_name': 'Crop Area and Production by State', 'source_url': 'https://www.dosm.gov.my', 'data_year': '2017-2022', 'file_name': 'crops_state (1).csv', 'chunk_id': 'chunk_000002', 'created_at': '2025-10-25T02:15:57.456035'}]

# %% [markdown]
# #### Step 3 : Embedding
# > - gonna use local embedding = transformer - cuda

# %%
import torch
from sentence_transformers import SentenceTransformer

# cuda
device = "cuda" if torch.cuda.is_available() else "cpu"
model = SentenceTransformer('all-MiniLM-L6-v2', device=device)

# model.to(device)

# %%
texts = [chunk["text"] for chunk in chunks]
embeddings = model.encode(texts, show_progress_bar=True, convert_to_tensor=False)

for i, chunk in enumerate(chunks):
    chunk["vector"] = embeddings[i].tolist()
# Out:
# Batches:   0%|          | 0/27 [00:00<?, ?it/s]
# Batches: 100%|██████████| 27/27 [00:01<00:00, 16.25it/s]

# %%
print(chunks[0])
print(f"total : {len(chunks)} chunks")
# Out:
# {'text': 'In Malaysia, on 2017-01-01, the crop type is cash_crops with a planted area of 20763.1 hectares that produced 217847.5 tonnes.', 'state': 'Malaysia', 'date': '2017-01-01', 'crop_type': 'cash_crops', 'planted_area': 20763.1, 'production': 217847.5, 'source': 'Department of Statistics Malaysia', 'dataset_name': 'Crop Area and Production by State', 'source_url': 'https://www.dosm.gov.my', 'data_year': '2017-2022', 'file_name': 'crops_state (1).csv', 'chunk_id': 'chunk_000001', 'created_at': '2025-10-25T02:15:57.455629', 'vector': [0.009799950756132603, 0.04136119782924652, -0.020146677270531654, -0.006750763393938541, 0.01361558586359024, -0.061234068125486374, 0.019660567864775658, -0.0285214651376009, -0.05232812464237213, -0.009885789826512337, 0.08972034603357315, -0.14824290573596954, -0.02272200584411621, -0.027730803936719894, -0.030332693830132484, 0.02045491151511669, 0.009871172718703747, -0.06126254424452782, -0.04810376465320587, -0.008865313604474068, 0.09607900679111481, 0.039179448038339615, 0.01870267279446125, -0.008588068187236786, -0.008279243484139442, -0.05156630277633667, -0.011758789420127869, 0.014038954861462116, -0.00032261264277622104, -0.0544554740190506, 0.0027266130782663822, 0.2112322747707367, 0.10565865784883499, -0.00962436106055975, 0.01881772093474865, 0.020526612177491188, -0.02037973143160343, 0.04395477473735809, 0.05492815747857094, 0.051608674228191376, -0.0008180666482076049, -0.034261707216501236, 0.08126816898584366, -0.0719781443476677, 0.02768111787736416, -0.1011001393198967, 0.005636020563542843, 0.026138756424188614, -0.01160628255456686, -0.02143809385597706, 0.05542904511094093, 0.05444910749793053, -0.0880795270204544, 0.004859241656959057, 0.034852534532547, -0.12665849924087524, 0.02340284362435341, 0.06535207480192184, -0.06393679231405258, 0.006779260467737913, 0.059955742210149765, 0.021952105686068535, -0.024012526497244835, -0.12197322398424149, -0.01633572019636631, 0.07886845618486404, -0.011058344505727291, -0.06095844507217407, -0.0018908033380284905, -0.06557401269674301, -0.05838748440146446, -0.02127125672996044, 0.01714981161057949, 0.027213742956519127, -0.08967133611440659, -0.01177421398460865, 0.06607229262590408, -0.02476021833717823, -0.0046118260361254215, -0.0755641907453537, -0.029485678300261497, 0.04624135419726372, -0.015640538185834885, -0.06472177803516388, -0.015020081773400307, -0.029692862182855606, 0.0012372853234410286, 0.05547108128666878, 0.1185867115855217, 0.05597924813628197, -0.012165333144366741, -0.009186082519590855, 0.002953514689579606, 0.04286928474903107, -0.0610538125038147, -0.03160201385617256, 0.007150824181735516, -0.07304659485816956, 0.0658414289355278, -0.008706975728273392, 0.09847133606672287, 0.016046008095145226, 0.043727096170186996, -0.08164478093385696, -0.023949960246682167, 0.08272964507341385, -0.07514426857233047, -0.02499607764184475, 0.023153113201260567, 0.007558567449450493, -0.08613225072622299, 0.07874158024787903, -0.10562725365161896, -0.06516284495592117, -0.06188802421092987, 0.0029718384612351656, -0.005650259554386139, -0.06230985373258591, -0.05094051733613014, -0.026082616299390793, 0.06995771080255508, 0.005079633090645075, -0.04445609822869301, -0.051002226769924164, 0.08422879129648209, 0.02275078371167183, -0.002676843898370862, -1.8226065623438492e-33, -0.06424416601657867, -0.05511264503002167, 0.0893072858452797, 0.01593954488635063, -0.02397739142179489, -0.020351849496364594, 0.041767220944166183, -0.06586676090955734, 0.002704581944271922, -0.052642058581113815, -0.03712856024503708, -0.07990248501300812, -0.026783864945173264, 0.024795645847916603, 0.04115184769034386, -0.015332437120378017, -0.028661271557211876, -0.04832031950354576, -0.0312565378844738, 0.07789414376020432, -0.08492955565452576, 0.037087440490722656, -0.09618386626243591, -0.03404457867145538, 0.09164486080408096, 0.04775982350111008, 0.05744337663054466, -0.03691139817237854, 0.02622046507894993, 0.0239796973 ...
# total : 864 chunks

# %% [markdown]
# #### Step 4 : Upload to Zilliz Cloud and Upload

# %%
from pymilvus import MilvusClient
from agent.config import settings

client = MilvusClient(
    uri=settings.ZILLIZ_URL,
    token=settings.ZILLIZ_TOKEN
)

# %%
collection_name = "crop_by_state_data"

# drop collection if exists
if collection_name in client.list_collections():
    client.drop_collection(collection_name)

# Create collection if not exists
if collection_name not in client.list_collections():
    client.create_collection(
        collection_name=collection_name,
        dimension=384,  
        metric_type="COSINE",
        auto_id=True
    )

# %%
result = client.insert(collection_name=collection_name, data=chunks)
print(result)
# Out:
# {'insert_count': 864, 'ids': [461027871141728175, 461027871141728176, 461027871141728177, 461027871141728178, 461027871141728179, 461027871141728180, 461027871141728181, 461027871141728182, 461027871141728183, 461027871141728184, 461027871141728185, 461027871141728186, 461027871141728187, 461027871141728188, 461027871141728189, 461027871141728190, 461027871141728191, 461027871141728192, 461027871141728193, 461027871141728194, 461027871141728195, 461027871141728196, 461027871141728197, 461027871141728198, 461027871141728199, 461027871141728200, 461027871141728201, 461027871141728202, 461027871141728203, 461027871141728204, 461027871141728205, 461027871141728206, 461027871141728207, 461027871141728208, 461027871141728209, 461027871141728210, 461027871141728211, 461027871141728212, 461027871141728213, 461027871141728214, 461027871141728215, 461027871141728216, 461027871141728217, 461027871141728218, 461027871141728219, 461027871141728220, 461027871141728221, 461027871141728222, 461027871141728223, 461027871141728224, 461027871141728225, 461027871141728226, 461027871141728227, 461027871141728228, 461027871141728229, 461027871141728230, 461027871141728231, 461027871141728232, 461027871141728233, 461027871141728234, 461027871141728235, 461027871141728236, 461027871141728237, 461027871141728238, 461027871141728239, 461027871141728240, 461027871141728241, 461027871141728242, 461027871141728243, 461027871141728244, 461027871141728245, 461027871141728246, 461027871141728247, 461027871141728248, 461027871141728249, 461027871141728250, 461027871141728251, 461027871141728252, 461027871141728253, 461027871141728254, 461027871141728255, 461027871141728256, 461027871141728257, 461027871141728258, 461027871141728259, 461027871141728260, 461027871141728261, 461027871141728262, 461027871141728263, 461027871141728264, 461027871141728265, 461027871141728266, 461027871141728267, 461027871141728268, 461027871141728269, 461027871141728270, 461027871141728271, 461027871141728272, 461027871141728273, 461027871141728274, 461027871141728275, 461027871141728276, 461027871141728277, 461027871141728278, 461027871141728279, 461027871141728280, 461027871141728281, 461027871141728282, 461027871141728283, 461027871141728284, 461027871141728285, 461027871141728286, 461027871141728287, 461027871141728288, 461027871141728289, 461027871141728290, 461027871141728291, 461027871141728292, 461027871141728293, 461027871141728294, 461027871141728295, 461027871141728296, 461027871141728297, 461027871141728298, 461027871141728299, 461027871141728300, 461027871141728301, 461027871141728302, 461027871141728303, 461027871141728304, 461027871141728305, 461027871141728306, 461027871141728307, 461027871141728308, 461027871141728309, 461027871141728310, 461027871141728311, 461027871141728312, 461027871141728313, 461027871141728314, 461027871141728315, 461027871141728316, 461027871141728317, 461027871141728318, 461027871141728319, 461027871141728320, 461027871141728321, 461027871141728322, 461027871141728323, 461027871141728324, 461027871141728325, 461027871141728326, 461027871141728327, 461027871141728328, 461027871141728329, 461027871141728330, 461027871141728331, 461027871141728332, 461027871141728333, 461027871141728334, 461027871141728335, 461027871141728336, 461027871141728337, 461027871141728338, 461027871141728339, 461027871141728340, 461027871141728341, 461027871141728342, 461027871141728343, 461027871141728344, 461027871141728345, 461027871141728346, 461027871141728347, 461027871141728348, 461027871141728349, 461027871141728350, 461027871141728351, 461027871141728352, 461027871141728353, 461027871141728354, 461027871141728355, 461027871141728356, 461027871141728357, 461027871141728358, 461027871141728359, 461027871141728360, 461027871141728361, 461027871141728362, 461027871141728363, 461027871141728364, 461027871141728365, 461027871141728366, 461027871141728367, 461027871141728368, 461027871141728369, 461027871141728370, 461027871141728371, 461027871141728372, 4610278711 ...

# %%
client.flush(collection_name)

# %%
# print stats
print(client.get_collection_stats(collection_name))
# Out:
# {'row_count': 864}

# %% [markdown]
# #### Step 5 : Test the semantic search

# %%
from langchain_huggingface import HuggingFaceEmbeddings


device = "cuda" if torch.cuda.is_available() else "cpu"
device = "cpu"
embeddings_model = HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2', model_kwargs={'device': device})
client = MilvusClient(uri=settings.ZILLIZ_URL, token=settings.ZILLIZ_TOKEN)
collection_name = "crop_by_state_data"

# %%
def semantic_search(query, k):
  
    query_vector = embeddings_model.embed_query(query)
    
    results = client.search(
        collection_name=collection_name,
        data=[query_vector],
        limit=k,
        output_fields=[
            "text", "state", "date", "crop_type", "planted_area", "production",
            "source", "dataset_name", "source_url", "data_year",
            "chunk_id", "created_at"
        ]
    )  
    
     # json output
    json_results = []
    for hits in results:
        for hit in hits:
            json_results.append({
                "text": hit['entity']['text'],
                
                # data fields
                "state": hit['entity']['state'],
                "date": hit['entity']['date'],
                "crop_type": hit['entity']['crop_type'],
                "planted_area": hit['entity']['planted_area'],
                "production": hit['entity']['production'],
                
                # metadata
                "source": hit['entity']['source'],
                "dataset_name": hit['entity']['dataset_name'],
                "source_url": hit['entity']['source_url'],
                "data_year": hit['entity']['data_year'],
                
                # tracking
                "chunk_id": hit['entity']['chunk_id'],
                "created_at": hit['entity']['created_at'],
                
                # score
                "score": hit['distance']
            })
    
    return json_results

# %%
results = semantic_search("crop production in Johor", 12)

# %%
results
# Out:
# [{'text': 'In Johor, on 2021-01-01, the crop type is industrial_crops with a planted area of 12975.7 hectares that produced 123560.5 tonnes.',
#   'state': 'Johor',
#   'date': '2021-01-01',
#   'crop_type': 'industrial_crops',
#   'planted_area': 12975.7,
#   'production': 123560.5,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000089',
#   'created_at': '2025-10-25T02:15:57.474848',
#   'score': 0.8633418679237366},
#  {'text': 'In Johor, on 2020-01-01, the crop type is industrial_crops with a planted area of 12463.1 hectares that produced 110575.5 tonnes.',
#   'state': 'Johor',
#   'date': '2020-01-01',
#   'crop_type': 'industrial_crops',
#   'planted_area': 12463.1,
#   'production': 110575.5,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000088',
#   'created_at': '2025-10-25T02:15:57.474762',
#   'score': 0.8625238537788391},
#  {'text': 'In Johor, on 2019-01-01, the crop type is industrial_crops with a planted area of 11369.7 hectares that produced 102455.0 tonnes.',
#   'state': 'Johor',
#   'date': '2019-01-01',
#   'crop_type': 'industrial_crops',
#   'planted_area': 11369.7,
#   'production': 102455.0,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000087',
#   'created_at': '2025-10-25T02:15:57.474655',
#   'score': 0.8565560579299927},
#  {'text': 'In Johor, on 2017-01-01, the crop type is industrial_crops with a planted area of 16161.0 hectares that produced 117769.7 tonnes.',
#   'state': 'Johor',
#   'date': '2017-01-01',
#   'crop_type': 'industrial_crops',
#   'planted_area': 16161.0,
#   'production': 117769.7,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000085',
#   'created_at': '2025-10-25T02:15:57.474313',
#   'score': 0.8538245558738708},
#  {'text': 'In Johor, on 2022-01-01, the crop type is industrial_crops with a planted area of 13820.5 hectares that produced 128173.1 tonnes.',
#   'state': 'Johor',
#   'date': '2022-01-01',
#   'crop_type': 'industrial_crops',
#   'planted_area': 13820.5,
#   'production': 128173.1,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000090',
#   'created_at': '2025-10-25T02:15:57.474920',
#   'score': 0.8508120775222778},
#  {'text': 'In Johor, on 2018-01-01, the crop type is industrial_crops with a planted area of 13625.3 hectares that produced 98700.0 tonnes.',
#   'state': 'Johor',
#   'date': '2018-01-01',
#   'crop_type': 'industrial_crops',
#   'planted_area': 13625.3,
#   'production': 98700.0,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000086',
#   'created_at': '2025-10-25T02:15:57.474503',
#   'score': 0.8465734720230103},
#  {'text': 'In Johor, on 2020-01-01, the crop type is vegetables with a planted area of 14843.7 hectares that produced 208260.3 tonnes.',
#   'state': 'Johor',
#   'date': '2020-01-01',
#   'crop_type': 'vegetables',
#   'planted_area': 14843.7,
#   'production': 208260.3,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000106',
#   'created_at': '2025-10-25T02:15:57.477112',
#   'score': 0.8448514342308044},
#  {'text': 'In Johor, on 2018-01-01, the crop type is vegetables with a planted area of 14502.9 hectares that produced 198459.8 tonnes.',
#   'state': 'Johor',
#   'date': '2018-01-01',
#   'crop_type': 'vegetables',
#   'planted_area': 14502.9,
#   'production': 198459.8,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000104',
#   'created_at': '2025-10-25T02:15:57.476577',
#   'score': 0.840561032295227},
#  {'text': 'In Johor, on 2019-01-01, the crop type is vegetables with a planted area of 15359.3 hectares that produced 203996.5 tonnes.',
#   'state': 'Johor',
#   'date': '2019-01-01',
#   'crop_type': 'vegetables',
#   'planted_area': 15359.3,
#   'production': 203996.5,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000105',
#   'created_at': '2025-10-25T02:15:57.476852',
#   'score': 0.8398251533508301},
#  {'text': 'In Johor, on 2017-01-01, the crop type is fruits with a planted area of 59264.8 hectares that produced 603693.0 tonnes.',
#   'state': 'Johor',
#   'date': '2017-01-01',
#   'crop_type': 'fruits',
#   'planted_area': 59264.8,
#   'production': 603693.0,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000073',
#   'created_at': '2025-10-25T02:15:57.472924',
#   'score': 0.8390941023826599},
#  {'text': 'In Johor, on 2021-01-01, the crop type is vegetables with a planted area of 17186.9 hectares that produced 242213.7 tonnes.',
#   'state': 'Johor',
#   'date': '2021-01-01',
#   'crop_type': 'vegetables',
#   'planted_area': 17186.9,
#   'production': 242213.7,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000107',
#   'created_at': '2025-10-25T02:15:57.477285',
#   'score': 0.8383021354675293},
#  {'text': 'In Johor, on 2019-01-01, the crop type is fruits with a planted area of 41504.2 hectares that produced 543387.3 tonnes.',
#   'state': 'Johor',
#   'date': '2019-01-01',
#   'crop_type': 'fruits',
#   'planted_area': 41504.2,
#   'production': 543387.3,
#   'source': 'Department of Statistics Malaysia',
#   'dataset_name': 'Crop Area and Production by State',
#   'source_url': 'https://www.dosm.gov.my',
#   'data_year': '2017-2022',
#   'chunk_id': 'chunk_000075',
#   'created_at': '2025-10-25T02:15:57.473170',
#   'score': 0.8376721143722534}]
